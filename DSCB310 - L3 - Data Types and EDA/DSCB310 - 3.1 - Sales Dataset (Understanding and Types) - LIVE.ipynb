# %%
import pandas as pd
import numpy as np
#import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_csv("Sales Datensatz_groß.csv")

# %%
df.head()
# Out:
#    Store StoreType  StoreSize  DeptType        Date  IsHoliday  Temperature  \
# 0   10.0         B   126512.0      54.0  13/05/2011      False        74.04
# 1   29.0         B    93638.0      11.0  18/05/2012      False        61.90
# 2    2.0         A   202307.0      19.0  04/03/2011      False        57.77
# 3   35.0         B   103681.0      74.0  11/11/2011      False        49.69
# 4   38.0         C    39690.0      72.0  16/09/2011      False        76.36
#
#    FuelPrice  ConsumerPriceIndex  UnemploymentRate  WeeklySales  MarkDown1  \
# 0      4.202          129.089000             8.494       138.76        NaN
# 1      3.899          138.106581             9.140      7203.86    3018.19
# 2      3.288          213.477531             8.028      4588.08        NaN
# 3      3.530          140.411161             8.745     20907.55   22242.79
# 4      3.918          129.430600            13.503       313.53        NaN
#
#    MarkDown2  MarkDown3  MarkDown4  MarkDown5
# ...

# %%
df['Store'] = df.Store.astype('int')
df['DeptType'] = df.Store.astype('int')

# %%
df['Date'] = pd.to_datetime(df.Date)

# %%
# Prüfung bitte umsetzen: Validierung von WeeklySales - haben wir pro Store und Date wirklich immer nur 
# wöchentliche Absatzdaten, oder gibt es Wochen, in denen mehrere WeeklySales "gemeldet" wurden?
# Out:
#        Store StoreType  StoreSize  DeptType       Date  IsHoliday  \
# 0         10         B   126512.0        10 2011-05-13      False
# 1         29         B    93638.0        29 2012-05-18      False
# 2          2         A   202307.0         2 2011-04-03      False
# 3         35         B   103681.0        35 2011-11-11      False
# 4         38         C    39690.0        38 2011-09-16      False
# ...      ...       ...        ...       ...        ...        ...
# 84309     42         C    39690.0        42 2011-09-16      False
# 84310     27         A   204184.0        27 2012-03-23      False
# 84311     20         A   203742.0        20 2010-02-19      False
# 84312     23         B   114533.0        23 2011-05-13      False
# 84313     26         A   152513.0        26 2012-08-06      False
#
#        Temperature  FuelPrice  ConsumerPriceIndex  UnemploymentRate  \
# 0            74.04      4.202          129.089000             8.494
# ...
